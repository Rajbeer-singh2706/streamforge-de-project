# %% [markdown]
# ## **Chat1-desgining**

# %%
# I have share with you complete context and u have generate the plan as well to run the complete codebase 
now i would like to do in this chat as as architect(learning) what to do ?

# %% [markdown]
# ## **Chat2-code**

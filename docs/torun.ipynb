# %%
## to build only individual container
# docker compose build producer

# %%
# Best practices for developing dataenginnnering projects
# Architectural patterns for data engineering projects

# %%
## Medilian Architecture 
## how to define broze, silver, gold

# %%
# mke up 
# make ps

# %%
# make db-shell
'''
 \dt 
 \dT
 select * from v_subscription_summary;
'''
# make db-shell
'''
INSERT INTO subscriptions (customer_id, plan, status, expires_at, amount_usd) 
VALUES ('11111111-1111-1111-1111-111111111111', 'basic', 'Active', NOW(), 4.99);
'''

# %%
# open http://localhost:8080

# %%
#git add . && git commit -m "Day 3: Postgres schema + Kafka UI — full local stack running"

# %%
### DOCKER 
# docker-compose up -d zookeeper kafka
# docker-compose ps
# docker-compose up kafka-init
# make topics 
# docker exec -it sf_kafka kafka-console-producer --bootstrap-server localhost:29092 --topic sub.new_subscription
# docker exec sf_kafka kafka-console-consumer --bootstrap-server localhost:29092 --topic sub.new_subscription --from-beginning --max-messages 1
uv python list
uv venv --python 3.12
.venv\Scripts\activate
uv init
>uv add -r requirements.txt
## git bash terminal
git init && git branch -M main
touch .gitignore .env.example README.md Makefile docker-compose.yml
mkdir -p scripts && touch scripts/create_topics.sh && chmod +x scripts/create_topics.sh
